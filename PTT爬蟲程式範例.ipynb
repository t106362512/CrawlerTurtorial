# %% [markdown]
# #### 爬蟲範例：ptt網站爬取流程
#
# 1.從首頁進入
# 2.設定cookie
# 3.取得此頁所有文章的連結
# 4.對各文章原始碼進行處理
#
# https://github.com/Openbox7681/CrawlerTurtorial

# %% [markdown]
# 裝5.X.X版本的 elasticsearch

# %%
# !pip install elasticsearch==5.5.3
# Out:
# Requirement already satisfied: elasticsearch==5.5.3 in /usr/local/lib/python3.6/dist-packages (5.5.3)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from elasticsearch==5.5.3) (1.24.3)

# %%
import requests
from bs4 import BeautifulSoup
from datetime import timedelta
import json

#從首頁進入並設定cookie


ptt = "https://www.ptt.cc"
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
s = requests.Session()
s.post(ptt + "/ask/over18", data={'yes': 'yes'})
page = s.get(url).text

soup = BeautifulSoup(page, features="html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# <a class="btn" href="/man/Gossiping/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Gossiping/index38945.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100740.A.36D.html">[問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？</a>
# </div>
# <div class="meta">
# <div class="author">Qoo20811</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%AC%B8%EF%BC%81%E5%89%9B%E5%89%9B%E5%9C%A8%E9%9B%BB%E8%BB%8A%E4%B8%8A%E8%B7%9F%E9%86%89%E6%BC%A2%E6%89%93%E6%9E%B6%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AQoo20811">搜尋看板內 Qoo20811 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100778.A.A7A.html">[問卦] 木曜一日有辦法重返榮耀嗎</a>
# </div>
# <div class="meta">
# <div class="author">cezov0514</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%9C%A8%E6%9B%9C%E4%B8%80%E6%97%A5%E6%9C%89%E8%BE%A6%E6%B3%95%E9%87%8D%E8%BF%94%E6%A6%AE%E8%80%80%E5%97%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Acezov0514">搜尋看板內 cezov0514 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100800.A.31B.html">[新聞] 特朗普與習近平和安倍就朝鮮問題進行連</a>
# </div>
# <div class="meta">
# <div class="author">andrewkuo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%89%B9%E6%9C%97%E6%99%AE%E8%88%87%E7%BF%92%E8%BF%91%E5%B9%B3%E5%92%8C%E5%AE%89%E5%80%8D%E5%B0%B1%E6%9C%9D%E9%AE%AE%E5%95%8F%E9%A1%8C%E9%80%B2%E8%A1%8C%E9%80%A3">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aandrewkuo">搜尋看板內 andrewkuo 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100804.A.A6A.html">Re: [新聞] 全年赴日逼近千萬人次 陸客眼中日本仍有</a>
# </div>
# <div class="meta">
# <div class="author">racers</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%85%A8%E5%B9%B4%E8%B5%B4%E6%97%A5%E9%80%BC%E8%BF%91%E5%8D%83%E8%90%AC%E4%BA%BA%E6%AC%A1+%E9%99%B8%E5%AE%A2%E7%9C%BC%E4%B8%AD%E6%97%A5%E6%9C%AC%E4%BB%8D%E6%9C%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aracers">搜尋看板內 racers 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100836.A.48E.html">[問卦] 看到鄉民在看PTT當下該怎麼辦？</a>
# </div>
# <div class="meta">
# <div class="author">johnhmj</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%9C%8B%E5%88%B0%E9%84%89%E6%B0%91%E5%9C%A8%E7%9C%8BPTT%E7%95%B6%E4%B8%8B%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajohnhmj">搜尋看板內 johnhmj 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100893.A.B9A.html">Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？</a>
# </div>
# <div class="meta">
# <div class="author">willie7878</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%88%B8%E5%AA%BD%E9%83%BD%E6%98%AF%E7%8B%82%E7%86%B1%E9%9F%93%E7%B2%89%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3
的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101261.A.961.html">Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天</a>
# </div>
# <div class="meta">
# <div class="author">chuhao</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%BD%B7%E9%9F%93%E4%BA%8C%E9%9A%8E%E9%80%A3%E7%BD%B2%E5%8D%B3%E5%B0%87%E9%96%8B%E8%B7%91%EF%BC%81+%E5%85%AC%E6%B0%91%E5%89%B2%E8%8D%89%E7%9B%BC60%E5%A4%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Achuhao">搜尋看板內 chuhao 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101402.A.33C.html">Re: [問卦] 1歲以下不能親 1歲以上可以親?</a>
# </div>
# <div class="meta">
# <div class="author">godispower</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+1%E6%AD%B2%E4%BB%A5%E4%B8%8B%E4%B8%8D%E8%83%BD%E8%A6%AA+1%E6%AD%B2%E4%BB%A5%E4%B8%8A%E5%8F%AF%E4%BB%A5%E8%A6%AA%3F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Agodispower">搜尋看板內 godispower 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101414.A.973.html">[新聞] 女嬰遭韓國瑜又抱又親 爸爸怒了：沒有不</a>
# </div>
# <div class="meta">
# <div class="author">koheik2</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%A5%B3%E5%AC%B0%E9%81%AD%E9%9F%93%E5%9C%8B%E7%91%9C%E5%8F%88%E6%8A%B1%E5%8F%88%E8%A6%AA+%E7%88%B8%E7%88%B8%E6%80%92%E4%BA%86%EF%BC%9A%E6%B2%92%E6%9C%89%E4%B8%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Akoheik2">搜尋看板內 koheik2 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101416.A.B56.html">[問卦] 前女友很上進  自己很廢怎麼辦</a>
# </div>
# <div class="meta">
# <div class="author">sweet79731</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%89%8D%E5%A5%B3%E5%8F%8B%E5%BE%88%E4%B8%8A%E9%80%B2++%E8%87%AA%E5%B7%B1%E5%BE%88%E5%BB%A2%E6%80%8E%E9%BA%BC%E8%BE%A6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asweet79731">搜尋看板內 sweet79731 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101519.A.AA0.html">Re: [問卦] 明年1/11投票</a>
# </div>
# <div class="meta">
# <div class="author">JAL96</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%98%8E%E5%B9%B41%2F11%E6%8A%95%E7%A5%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AJAL96">搜尋看板內 JAL96 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577101541.A.152.html">[問卦] 在社會上只是坨屎是什麼感覺</a>
# </div>
# <div class="meta">
# <div class="author">babylickme</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%9C%A8%E7%A4%BE%E6%9C%83%E4%B8%8A%E5%8F%AA%E6%98%AF%E5%9D%A8%E5%B1%8E%E6%98%AF%E4%BB%80%E9%BA%BC%E6%84%9F%E8%A6%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Ababylickme">搜尋看板內 babylickme 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1566347622.A.9C7.html">[公告] 八卦板板規(2019.08.21)</a>
# </div>
# <div class="meta">
# <div class="author">arsonlolita</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282019.08.21%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/21</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1576589328.A.1F3.html">[協尋] 協尋雲林縣崙背鄉前代表廖先生</a>
# </div>
# <div class="meta">
# <div class="author">asseee</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+%E5%8D%94%E5%B0%8B%E9%9B%B2%E6%9E%97%E7%B8%A3%E5%B4%99%E8%83%8C%E9%84%89%E5%89%8D%E4%BB%A3%E8%A1%A8%E5%BB%96%E5%85%88%E7%94%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aasseee">搜尋看板內 asseee 的文章</a></div>
# </div>
# </div>
# <div class="date">12/17</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">73</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1576672094.A.A23.html">[協尋] 妹妹與友人失蹤 代po</a>
# </div>
# <div class="meta">
# <div class="author">wonling</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+%E5%A6%B9%E5%A6%B9%E8%88%87%E5%8F%8B%E4%BA%BA%E5%A4%B1%E8%B9%A4+%E4%BB%A3po">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awonling">搜尋看板內 wonling 的文章</a></div>
# </div>
# </div>
# <div class="date">12/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1576742959.A.429.html">[協尋] 行車記錄器 高雄區/鳳山區 </a>
# </div>
# <div class="meta">
# <div class="author">arsonlolita</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8+%E9%AB%98%E9%9B%84%E5%8D%80%2F%E9%B3%B3%E5%B1%B1%E5%8D%80+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
# </div>
# </div>
# <div class="date">12/19</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1575299597.A.058.html">[公告] 一劍無悔，十二月置底閒聊文</a>
# </div>
# <div class="meta">
# <div class="author">Bignana</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E4%B8%80%E5%8A%8D%E7%84%A1%E6%82%94%EF%BC%8C%E5%8D%81%E4%BA%8C%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E6%96%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ABignana">搜尋看板內 Bignana 的文章</a></div>
# </div>
# </div>
# <div class="date">12/02</div>
# <div class="mark">M</div>
# </div>
# </div>
# </div>
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
##發現文章位於 div 標籤的 r-ent class先往下解析一層
soup = BeautifulSoup(page, features="html.parser")
divs = soup.find_all('div', class_='r-ent')
for div in divs:
    print(div)
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">3</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100740.A.36D.html">[問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？</a>
# </div>
# <div class="meta">
# <div class="author">Qoo20811</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%AC%B8%EF%BC%81%E5%89%9B%E5%89%9B%E5%9C%A8%E9%9B%BB%E8%BB%8A%E4%B8%8A%E8%B7%9F%E9%86%89%E6%BC%A2%E6%89%93%E6%9E%B6%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AQoo20811">搜尋看板內 Qoo20811 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100778.A.A7A.html">[問卦] 木曜一日有辦法重返榮耀嗎</a>
# </div>
# <div class="meta">
# <div class="author">cezov0514</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%9C%A8%E6%9B%9C%E4%B8%80%E6%97%A5%E6%9C%89%E8%BE%A6%E6%B3%95%E9%87%8D%E8%BF%94%E6%A6%AE%E8%80%80%E5%97%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Acezov0514">搜尋看板內 cezov0514 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100800.A.31B.html">[新聞] 特朗普與習近平和安倍就朝鮮問題進行連</a>
# </div>
# <div class="meta">
# <div class="author">andrewkuo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%89%B9%E6%9C%97%E6%99%AE%E8%88%87%E7%BF%92%E8%BF%91%E5%B9%B3%E5%92%8C%E5%AE%89%E5%80%8D%E5%B0%B1%E6%9C%9D%E9%AE%AE%E5%95%8F%E9%A1%8C%E9%80%B2%E8%A1%8C%E9%80%A3">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aandrewkuo">搜尋看板內 andrewkuo 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100804.A.A6A.html">Re: [新聞] 全年赴日逼近千萬人次 陸客眼中日本仍有</a>
# </div>
# <div class="meta">
# <div class="author">racers</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%85%A8%E5%B9%B4%E8%B5%B4%E6%97%A5%E9%80%BC%E8%BF%91%E5%8D%83%E8%90%AC%E4%BA%BA%E6%AC%A1+%E9%99%B8%E5%AE%A2%E7%9C%BC%E4%B8%AD%E6%97%A5%E6%9C%AC%E4%BB%8D%E6%9C%89">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aracers">搜尋看板內 racers 的文章</a></div>
# </div>
# </div>
# <div class="date">12/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1577100836.A.48E.html">[問卦] 看到鄉民在看PTT當下該怎麼辦？</a>
# </div>
# <div class="meta">
# <div class="author">johnhmj</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E7%9C%8B%E5%88%B0%E9%84%89%E6%B0%91%E5%9C%A8%E7%9C%8BPTT%E7%95%B6%E4%B8%8B%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BE%A6%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3
9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aasseee">搜尋看板內 asseee 的文章</a></div>
# </div>
# </div>
# <div class="date">12/17</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">73</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1576672094.A.A23.html">[協尋] 妹妹與友人失蹤 代po</a>
# </div>
# <div class="meta">
# <div class="author">wonling</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+%E5%A6%B9%E5%A6%B9%E8%88%87%E5%8F%8B%E4%BA%BA%E5%A4%B1%E8%B9%A4+%E4%BB%A3po">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awonling">搜尋看板內 wonling 的文章</a></div>
# </div>
# </div>
# <div class="date">12/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1576742959.A.429.html">[協尋] 行車記錄器 高雄區/鳳山區 </a>
# </div>
# <div class="meta">
# <div class="author">arsonlolita</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8+%E9%AB%98%E9%9B%84%E5%8D%80%2F%E9%B3%B3%E5%B1%B1%E5%8D%80+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
# </div>
# </div>
# <div class="date">12/19</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">9</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1575299597.A.058.html">[公告] 一劍無悔，十二月置底閒聊文</a>
# </div>
# <div class="meta">
# <div class="author">Bignana</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E4%B8%80%E5%8A%8D%E7%84%A1%E6%82%94%EF%BC%8C%E5%8D%81%E4%BA%8C%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E6%96%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3ABignana">搜尋看板內 Bignana 的文章</a></div>
# </div>
# </div>
# <div class="date">12/02</div>
# <div class="mark">M</div>
# </div>
# </div>

# %%
##發現文章位於 div 標籤的 r-ent class先往下解析一層
soup = BeautifulSoup(page, features="html.parser")
divs = soup.find_all('div', class_='r-ent')
for div in divs:
    ptt = "https://www.ptt.cc"
    soup_title = BeautifulSoup(str(div), features="html.parser")
    ##解析標題的div結構
    title = soup_title.find_all('div', class_='title')
    news_title = title[0].text.strip()
    ##取得標題文章內文之連結
    try:
        link = title[0].find('a')['href'].strip()
    except:
        continue
    print(news_title)
    print(ptt + link)
# Out:
# [問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100740.A.36D.html
# [問卦] 木曜一日有辦法重返榮耀嗎
# https://www.ptt.cc/bbs/Gossiping/M.1577100778.A.A7A.html
# [新聞] 特朗普與習近平和安倍就朝鮮問題進行連
# https://www.ptt.cc/bbs/Gossiping/M.1577100800.A.31B.html
# Re: [新聞] 全年赴日逼近千萬人次 陸客眼中日本仍有
# https://www.ptt.cc/bbs/Gossiping/M.1577100804.A.A6A.html
# [問卦] 看到鄉民在看PTT當下該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100836.A.48E.html
# Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100893.A.B9A.html
# [問卦] 玩交換肥宅會很好玩嗎？☺☺☺
# https://www.ptt.cc/bbs/Gossiping/M.1577100979.A.FA7.html
# Re: [爆卦] 姜冠宇醫師出來說話啦
# https://www.ptt.cc/bbs/Gossiping/M.1577100983.A.BCD.html
# [新聞] 韓美特戰部隊斬首軍演 向北韓傳遞強烈警
# https://www.ptt.cc/bbs/Gossiping/M.1577101093.A.32F.html
# [新聞] 高市推400億山海經樂園 她酸 :「結成愛情
# https://www.ptt.cc/bbs/Gossiping/M.1577101105.A.C44.html
# Re: [問卦] Bon jovi樂團哪一首歌最經典
# https://www.ptt.cc/bbs/Gossiping/M.1577101139.A.9E4.html
# [問卦] 能忍多久不看ptt?
# https://www.ptt.cc/bbs/Gossiping/M.1577101245.A.854.html
# Re: [問卦] 和中國學生妹交往
# https://www.ptt.cc/bbs/Gossiping/M.1577101249.A.5D0.html
# [問卦] 政府要你做壞事你會拒絕嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.E8B.html
# Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.961.html
# Re: [問卦] 1歲以下不能親 1歲以上可以親?
# https://www.ptt.cc/bbs/Gossiping/M.1577101402.A.33C.html
# [新聞] 女嬰遭韓國瑜又抱又親 爸爸怒了：沒有不
# https://www.ptt.cc/bbs/Gossiping/M.1577101414.A.973.html
# [問卦] 前女友很上進  自己很廢怎麼辦
# https://www.ptt.cc/bbs/Gossiping/M.1577101416.A.B56.html
# Re: [問卦] 明年1/11投票
# https://www.ptt.cc/bbs/Gossiping/M.1577101519.A.AA0.html
# [問卦] 在社會上只是坨屎是什麼感覺
# https://www.ptt.cc/bbs/Gossiping/M.1577101541.A.152.html
# [公告] 八卦板板規(2019.08.21)
# https://www.ptt.cc/bbs/Gossiping/M.1566347622.A.9C7.html
# [協尋] 協尋雲林縣崙背鄉前代表廖先生
# https://www.ptt.cc/bbs/Gossiping/M.1576589328.A.1F3.html
# [協尋] 妹妹與友人失蹤 代po
# https://www.ptt.cc/bbs/Gossiping/M.1576672094.A.A23.html
# [協尋] 行車記錄器 高雄區/鳳山區
# https://www.ptt.cc/bbs/Gossiping/M.1576742959.A.429.html
# [公告] 一劍無悔，十二月置底閒聊文
# https://www.ptt.cc/bbs/Gossiping/M.1575299597.A.058.html

# %%
import requests
from bs4 import BeautifulSoup
from datetime import timedelta
import json

#從首頁進入並設定cookie


ptt = "https://www.ptt.cc"
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
s = requests.Session()
s.post(ptt + "/ask/over18", data={'yes': 'yes'})
page = s.get(url).text

soup = BeautifulSoup(page, features="html.parser")
divs = soup.find_all('div', class_='r-ent')
for div in divs:
    soup_title = BeautifulSoup(str(div), features="html.parser")
    title = soup_title.find_all('div', class_='title')
    news_title = title[0].text.strip()
    try:
        link = title[0].find('a')['href'].strip()
    except:
        continue
    
    if '[公告]' in news_title or '[協尋]' in news_title:
            continue
    print(news_title)
    print(ptt + link)
# Out:
# [問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100740.A.36D.html
# [問卦] 木曜一日有辦法重返榮耀嗎
# https://www.ptt.cc/bbs/Gossiping/M.1577100778.A.A7A.html
# [新聞] 特朗普與習近平和安倍就朝鮮問題進行連
# https://www.ptt.cc/bbs/Gossiping/M.1577100800.A.31B.html
# Re: [新聞] 全年赴日逼近千萬人次 陸客眼中日本仍有
# https://www.ptt.cc/bbs/Gossiping/M.1577100804.A.A6A.html
# [問卦] 看到鄉民在看PTT當下該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100836.A.48E.html
# Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100893.A.B9A.html
# [問卦] 玩交換肥宅會很好玩嗎？☺☺☺
# https://www.ptt.cc/bbs/Gossiping/M.1577100979.A.FA7.html
# Re: [爆卦] 姜冠宇醫師出來說話啦
# https://www.ptt.cc/bbs/Gossiping/M.1577100983.A.BCD.html
# [新聞] 韓美特戰部隊斬首軍演 向北韓傳遞強烈警
# https://www.ptt.cc/bbs/Gossiping/M.1577101093.A.32F.html
# [新聞] 高市推400億山海經樂園 她酸 :「結成愛情
# https://www.ptt.cc/bbs/Gossiping/M.1577101105.A.C44.html
# Re: [問卦] Bon jovi樂團哪一首歌最經典
# https://www.ptt.cc/bbs/Gossiping/M.1577101139.A.9E4.html
# [問卦] 能忍多久不看ptt?
# https://www.ptt.cc/bbs/Gossiping/M.1577101245.A.854.html
# Re: [問卦] 和中國學生妹交往
# https://www.ptt.cc/bbs/Gossiping/M.1577101249.A.5D0.html
# [問卦] 政府要你做壞事你會拒絕嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.E8B.html
# Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.961.html
# Re: [問卦] 1歲以下不能親 1歲以上可以親?
# https://www.ptt.cc/bbs/Gossiping/M.1577101402.A.33C.html
# [新聞] 女嬰遭韓國瑜又抱又親 爸爸怒了：沒有不
# https://www.ptt.cc/bbs/Gossiping/M.1577101414.A.973.html
# [問卦] 前女友很上進  自己很廢怎麼辦
# https://www.ptt.cc/bbs/Gossiping/M.1577101416.A.B56.html
# Re: [問卦] 明年1/11投票
# https://www.ptt.cc/bbs/Gossiping/M.1577101519.A.AA0.html
# [問卦] 在社會上只是坨屎是什麼感覺
# https://www.ptt.cc/bbs/Gossiping/M.1577101541.A.152.html

# %%
#取得文章標題與連結
def get_links_from_index(page):
    soup = BeautifulSoup(page, features="html.parser")
    divs = soup.find_all('div', class_='r-ent')
    linkList = list()
    for div in divs:
        soup_title = BeautifulSoup(str(div), features="html.parser")
        title = soup_title.find_all('div', class_='title')
        news_title = title[0].text.strip()
        try:
            link = title[0].find('a')['href'].strip()
        except:
            continue
        if '[公告]' in news_title or '[協尋]' in news_title:
            continue
        linkList.append([news_title, link])
    # 因為每一個 index.html中的文章，最新的那篇是在最底下，所以做個 reversed
    # 這樣最新的文章就會是在 linkList[0]
    linkList = list(reversed(linkList))
    return linkList

# %%
##將上述程式碼組合
linkList= get_links_from_index(page)
for title, link in linkList:
    print(title)
    print(ptt + link)
# Out:
# [問卦] 在社會上只是坨屎是什麼感覺
# https://www.ptt.cc/bbs/Gossiping/M.1577101541.A.152.html
# Re: [問卦] 明年1/11投票
# https://www.ptt.cc/bbs/Gossiping/M.1577101519.A.AA0.html
# [問卦] 前女友很上進  自己很廢怎麼辦
# https://www.ptt.cc/bbs/Gossiping/M.1577101416.A.B56.html
# [新聞] 女嬰遭韓國瑜又抱又親 爸爸怒了：沒有不
# https://www.ptt.cc/bbs/Gossiping/M.1577101414.A.973.html
# Re: [問卦] 1歲以下不能親 1歲以上可以親?
# https://www.ptt.cc/bbs/Gossiping/M.1577101402.A.33C.html
# Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.961.html
# [問卦] 政府要你做壞事你會拒絕嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.E8B.html
# Re: [問卦] 和中國學生妹交往
# https://www.ptt.cc/bbs/Gossiping/M.1577101249.A.5D0.html
# [問卦] 能忍多久不看ptt?
# https://www.ptt.cc/bbs/Gossiping/M.1577101245.A.854.html
# Re: [問卦] Bon jovi樂團哪一首歌最經典
# https://www.ptt.cc/bbs/Gossiping/M.1577101139.A.9E4.html
# [新聞] 高市推400億山海經樂園 她酸 :「結成愛情
# https://www.ptt.cc/bbs/Gossiping/M.1577101105.A.C44.html
# [新聞] 韓美特戰部隊斬首軍演 向北韓傳遞強烈警
# https://www.ptt.cc/bbs/Gossiping/M.1577101093.A.32F.html
# Re: [爆卦] 姜冠宇醫師出來說話啦
# https://www.ptt.cc/bbs/Gossiping/M.1577100983.A.BCD.html
# [問卦] 玩交換肥宅會很好玩嗎？☺☺☺
# https://www.ptt.cc/bbs/Gossiping/M.1577100979.A.FA7.html
# Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100893.A.B9A.html
# [問卦] 看到鄉民在看PTT當下該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100836.A.48E.html
# Re: [新聞] 全年赴日逼近千萬人次 陸客眼中日本仍有
# https://www.ptt.cc/bbs/Gossiping/M.1577100804.A.A6A.html
# [新聞] 特朗普與習近平和安倍就朝鮮問題進行連
# https://www.ptt.cc/bbs/Gossiping/M.1577100800.A.31B.html
# [問卦] 木曜一日有辦法重返榮耀嗎
# https://www.ptt.cc/bbs/Gossiping/M.1577100778.A.A7A.html
# [問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100740.A.36D.html

# %%
#對個文章原始碼進行處理
def get_news_content(link, html):
    soup = BeautifulSoup(html, features="html.parser")
    meta = soup.find_all('span', class_="article-meta-value")
    try:
        author = meta[0].text
        title = meta[2].text
        time = meta[3].text
    except:
        return None
    txt = soup.find('div', id="main-content")
    f2 = soup.find_all('span', class_="f2")
    cut_link = ""
    
    for i in f2:
        if link in i.text:
            cut_link = i.text
            break
            
    txt_next = txt.text.split(meta[3].text)
    
    txt_final = txt_next[1].split(cut_link)
    cont = txt_final[0]

   
    txt_next = txt.text.split(meta[3].text)
    try:
        news = {
            'Title': title,
            'URL': link,
            'Author': author,
            'Description': cont,
        }
        print(news)
        return news

    except Exception as e:
        print(e)
        return None

# %%
##將上述程式碼組合
linkList= get_links_from_index(page)
for title, link in linkList:
    print(title)
    print(ptt + link)
    html = s.get(ptt + link).text
    content = get_news_content(ptt + link,html)
# Out:
# [問卦] 在社會上只是坨屎是什麼感覺
# https://www.ptt.cc/bbs/Gossiping/M.1577101541.A.152.html
# {'Title': '[問卦] 在社會上只是坨屎是什麼感覺', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101541.A.152.html', 'Author': 'babylickme (當白雪染遍了街頭...)', 'Description': '\n\n我是說我自己啦\n\n小時候還蠻受長輩疼愛的\n\n就覺得自己很重要偉大\n\n但出社會後發現只是陀屎\n\n這世界根本人外有人天外有天\n\n比你厲害的人太多了\n\n相比之下像陀屎\n\n尤其出社會跟小時後比那種感覺\n\n落差更大會有種很失望失落感\n\n怎辦？有解？哈囉？\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 49.216.44.9 (臺灣)\n'}
# Re: [問卦] 明年1/11投票
# https://www.ptt.cc/bbs/Gossiping/M.1577101519.A.AA0.html
# {'Title': 'Re: [問卦] 明年1/11投票', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577
n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 123.241.79.86 (臺灣)\n'}
# Re: [問卦] 1歲以下不能親 1歲以上可以親?
# https://www.ptt.cc/bbs/Gossiping/M.1577101402.A.33C.html
# {'Title': 'Re: [問卦] 1歲以下不能親 1歲以上可以親?', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101402.A.33C.html', 'Author': 'godispower (親愛的 .別鬧了)', 'Description': '\n其實你們仔細想想\n\n你的寶貝願不願意給一個\n\n滿嘴香菸喝酒 的人抱抱親親\n\n今天孩子會哭， 好像討論串裡面都沒有看到是\n\n寶寶因為聞到煙味或者是聞到酒味不習慣而哭？\n\n長期的喝酒香菸， 去親一個1歲不到的寶寶\n\n你是家長你願意嗎？\n\n※ 引述《ckk007 (~_~")》之銘言：\n: 剛剛有人告訴我\n: 1歲以下不能親 因為怕感染得病\n: 但1歲以上就可以親 因為免疫力強\n: 這個是不是真的?\n\n\n-----\nSent from JPTT on my Samsung SM-T235Y.\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 101.137.191.230 (臺灣)\n'}
# Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.961.html
# {'Title': 'Re: [新聞] 罷韓二階連署即將開跑！ 公民割草盼60天', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.961.html', 'Author': 'chuhao (自以為多數的少數..)', 'Description': '\n: : https://news.cts.com.tw/cts/politics/201912/201912231985105.html\n: 選罷法要罷免掉一個人這麼困難\n: kmt應該是超怕自己的人被罷免\n: 才會把罷免門檻弄到這麼高\n: https://news.ltn.com.tw/news/politics/breakingnews/1634241\n: 選罷法修正案進入審查！高志鵬：國民黨過去擋46次\n: 如果不是國民黨阻擋修法\n: 現在韓國瑜就等著被雙殺了\n\n  噁不噁心啊..這樣子出來帶風向幫民黨進擦脂抹粉，現在的選罷法修正案\n\n  明明就是資進黨的版本啊，最新的受益人不就是黃國昌議員嗎？\n\n  https://www.setn.com/News.aspx?NewsID=326488\n  人數沒過門檻…「罷昌失敗」竟是民進黨救了黃國昌！\n\n  時代力量立委黃國昌罷免案雖然有驚無險，最後罷免人數沒有過門檻「罷昌失敗」\n，不過，在他的戶籍地汐止白雲里同意罷免票數高過不同意票，進一步看，要不是\n  通過的是民進黨立委高志鵬所提「同意票必須超過總選舉人數的四分之一」\n，如果依原本「時力黨團版」罷免通過簡單多數決，罷昌案恐怕達陣成功。\n\n  看看資進黨裡的管媽是怎麼說的\n  https://newtalk.tw/news/view/2017-12-17/107332\n  黃國昌驚險保住立委 管碧玲:民進黨版本救了他\n\n  結果現在還想把鍋甩給顧面桶，我只能說...選舉要到了到處放假消息\n  意圖帶風向..真的讓人噁心\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 49.217.34.191 (臺灣)\n'}
# [問卦] 政府要你做壞事你會拒絕嗎？
# https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.E8B.html
# {'Title': '[問卦] 政府要你做壞事你會拒絕嗎？', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101261.A.E8B.html', 'Author': 'milkBK (blitzkrieg比較低)', 'Description': '\n假設你是個警察\n然後今天政府要你去打人、殺人\n你會放下這個飯碗離開嗎？\n\n如果是我的話應該只能低聲下氣去做\n不過也會在職務上消極\n假裝鎮壓不了、假裝開不了槍\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 36.229.149.103 (臺灣)\n'}
# Re: [問卦] 和中國學生妹交往
# https://www.ptt.cc/bbs/Gossiping/M.1577101249.A.5D0.html
# {'Title': 'Re: [問卦] 和中國學生妹交往', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101249.A.5D0.html', 'Author': 'CheDior (切迪奧)', 'Description': '\n※ 引述《aa0000000000 (...)》之銘言：\n: 看起來像是因應少子化\n: 台灣的大陸學生妹好像越來越多\n: 高中或大學都有陸生交流\n: 請問和大陸女生交往會發生哪些事情\n: 陸妹的家境都不好嗎?(來台唸書)\n: 台灣男生的口音、用詞會不會變成北京腔\n: 最後結婚要怎舉辦\n: 有八卦嗎\n: 謝謝\n\n我今年有交過一個中國妹子\n\n路上搭訕認識的，當初他還有男友\n\n不過她還是常常被我約出去玩\n\n去台北華山、大稻埕，甚至是南投鹿谷\n\n後來發現她好像喜歡上我了，超級主動的\n\n除了時不時跟我抱怨男友太無聊\n\n出去鹿谷玩那天直接傳line給我\n\n說在我車上差點忍不住親我\n\n後來主動跟男友分手，分手那天我們在一起\n\n五月交往，六月分手\n\n分手原因是她學期結束要回中國了\n\n有幾個心得\n\n1.家境超好，爸媽住石家莊市，職業都是醫生，我們出去玩幾乎都她出錢，吃500以上，最後一天還去清境住一晚6000、去台中吃了4000的麻辣鍋，算一算跟我交往這個月花了十萬有，BTW，我大她8歲\n\n2.觀念偏保守，覺得結婚前不能發生性行為，交過三任都還是處女，要照她的時程走，但身體很誠實，還沒交往前該做的都做了，只差插入，雖然硬來也行，但想想好像沒必要\n\n3.帶她去看當時在中正紀念堂64的氣球戰車，那幾天她來就是播64給她，還推薦他們圖書館裡面有的被中共禁的禁書，後來被我說服，覺得習近平是個垃圾\n\n4.講話幾乎沒口音，，應該說可以有兩種口音，因為雖然是河北人，但在廣州唸大學，已經很習慣南北口音轉來轉去\n\n5.是學霸...吧，河北省社會組大學考試全省一千名初頭，但頭腦沒說特別好，是死讀書上來的，她說中學的時候，一天唸16小時是常態，而且幾乎全校的人都是這樣，所以來台灣覺得台灣學生很不認真，而且非常訝異這邊的學生竟然在打工!(她來台灣唸的是銘傳)\n\n6.書看很多、電影看很多，我覺得應該是台灣大部分男生很愛的文青女，家教又好，衛生習慣也很好，衣服都是名牌，化妝品全是專櫃，每天用六至八種保養品，個人估算光每個月治裝加治妝應該超過30000，但頭髮很亂，髮質很糟，真心不懂為何不撥點錢在頭髮上\n\n\n身高174，有點瘦...但皮膚真的如嬰兒般\n\nhttps://imgur.com/dpFzsAJ\n\n\n\n\n\n-----\nSent from JPTT on my LGE LG-H870DS.\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 39.9.135.164 (臺灣)\n'}
# [問卦] 能忍多久不看ptt?
# https://www.ptt.cc/bbs/Gossiping/M.1577101245.A.854.html
# {'Title': '[問卦] 能忍多久不看ptt?', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101245.A.854.html', 'Author': 'jeff09122 (打ID不如打XD)', 'Description': '\n安安打給厚\n本宅發現自己只要有用手機就會開ptt滑一下\n就算東西都看過了還是會打開來滑\n一天沒看就好像全身不對勁\n除了上班忙不看之外\n其他時間只要有空就會打開來滑一下\n你各位啊可以忍受多久沒開ptt咧？\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自:
n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 123.241.239.251 (臺灣)\n'}
# [新聞] 韓美特戰部隊斬首軍演 向北韓傳遞強烈警
# https://www.ptt.cc/bbs/Gossiping/M.1577101093.A.32F.html
# {'Title': '[新聞] 韓美特戰部隊斬首軍演 向北韓傳遞強烈警', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577101093.A.32F.html', 'Author': 'idunhav1 (你知道天空為什麼是藍的?)', 'Description': '\n\n1.媒體來源:\n中央社\n\n2.記者署名\n姜遠珍\n\n3.完整新聞標題:\n韓美特戰部隊斬首軍演 向北韓傳遞強烈警告\n\n4.完整新聞內文:\n\nhttps://imgur.com/T3BS7NE\n南韓媒體23日報導，駐韓美軍特戰司令部11月與韓軍特戰隊員在群山基地實施聯合演訓，\n這一次美國國防部破例公開演習照片。（圖取自DVIDS網頁dvidshub.net）\n\n（中央社記者姜遠珍首爾23日專電）南韓媒體今天報導，駐韓美軍特戰司令部11月與韓軍\n特戰隊員在群山基地實施聯合演訓，突擊北韓軍事基地，及擒拿假想重要人物的「斬首行\n動」，對北韓傳遞強烈警告信號。\n\n南韓「朝鮮日報」今天報導，韓美特種部隊經常聯合演習，進行「斬首行動」訓練，這一\n次美國國防部破例公開演習照片。\n\n報導指出，韓美聲稱這一項訓練是「正規演習」，但軍方傳聞稱：「公開平時不公開的演\n習，是在向暗示『耶誕節挑釁』的北韓傳達強有力的軍事警告。」\n\n報導稱，美國國防部最近在相關網站公開12張照片，其中包括韓美特戰隊員今年8月至11\n月在群山、仁川和江原道附近進行的軍事訓練。\n\n由美國陸軍、海軍、空軍、陸戰隊組成的特戰隊員，在韓半島各地進行演習。特戰隊員搭\n乘CH-47直升機進行空降滲透訓練，並且在戰鬥機空中支援下，配備滅音步槍進行俘虜特\n定重要人物的斬首演練。\n\nhttps://imgur.com/L4qITrv\n美國國防部最近在相關網站公開12張照片，其中包括韓美特戰隊員今年8月至11月在群山\n、仁川和江原道附近進行的軍事訓練。（圖取自DVIDS網頁dvidshub.net）\n\n報導指出，美軍一度公開韓美聯軍與偽裝北韓軍對抗槍戰的影片畫面。據悉，美軍曾將影\n片上傳到國防部相關網站，但事涉敏感又刪除這一段畫面。\n\n去年美國與北韓展開對話後，一直沒有公開敏感的演習內容。有分析認為，北韓今年接連\n發射仿俄製伊斯坎德爾的KN-23飛彈和超大型火箭砲後，最近又暗示準備發射洲際彈道飛\n彈，因此美國公開軍演照片，其實是向北韓軍方發出警告，不排除採取「斬首行動」。\n\n報導稱，美國最近曾公開警告：「可能會回到2017年的軍事緊張局面。」 美軍公開提及\n「軍事選項」，加強對北韓發出警告信號。據分析，這一次公開韓美聯合演習照片，就是\n要向北韓領導人金正恩施加壓力。（編輯：王永志）1081223\n\n5.完整新聞連結 (或短網址):\nhttps://www.cna.com.tw/news/firstnews/201912230181.aspx\n\n6.備註:\n\n\n--\n    λλ    ╭───╮   Σ  ≡ ◎ ≡\n     ︱    ◣        海 水 退 潮                       〞∥〝\n    ︱ ● // ▼  ── 就 知 道 誰 沒 穿 褲 子\n Λ  ￣  ◢ㄩ◣\n ◢ ∫ ◣   ◥ ◤     ﹦   ◢██◤  ﹦            \n ● Y  ● ● Y  ●   ●"Y ● ◤  ◤              ◤    ⊕xgodtw \n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 122.116.195.139 (臺灣)\n'}
# Re: [爆卦] 姜冠宇醫師出來說話啦
# https://www.ptt.cc/bbs/Gossiping/M.1577100983.A.BCD.html
# {'Title': 'Re: [爆卦] 姜冠宇醫師出來說話啦', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100983.A.BCD.html', 'Author': 'tetani (喵喵)', 'Description': '\n※ 引述《JaredDudley (Jared Dudley)》之銘言：\n: 現在記者們在現場訪問姜冠宇醫師\n: 有記者問他說自己立場中立可是臉書大頭貼明顯支持民進黨\n: 他說雖然投票立場上是這樣可是政策方面他是中立\n: 還說昨天晚上接到很多通恐嚇電話揚言要告他\n: 自己很害怕\n: 嬰兒爸爸要提告現在會跟律師討論後續事宜\n: 並再次聲稱臉書上會貼照片發文是因為他有專科醫師執照\n: 需要宣導正確的衛教觀念\n\n大家應該支持這位醫師吧\n雖然做法有爭議\n但也是為了台灣好\n嘲諷的創意一多\n本來就容易出包一兩次\n大家笑一笑就好\n不用一直往死裡打\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 61.227.183.34 (臺灣)\n'}
# [問卦] 玩交換肥宅會很好玩嗎？☺☺☺
# https://www.ptt.cc/bbs/Gossiping/M.1577100979.A.FA7.html
# {'Title': '[問卦] 玩交換肥宅會很好玩嗎？☺☺☺', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100979.A.FA7.html', 'Author': 'gentleman888 ()', 'Description': '\n聖誕節快到了，\n\n交換禮物是其中受歡迎又好玩的活動，\n\n如果改玩交換肥宅，\n\n會很好玩嗎？☺☺☺\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 42.76.130.167 (臺灣)\n'}
# Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100893.A.B9A.html
# {'Title': 'Re: [問卦] 爸媽都是狂熱韓粉怎麼辦？', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100893.A.B9A.html', 'Author': 'willie7878 (威力78)', 'Description': '\n※ 引述 《youarenotgay》 之銘言：\n: 所以我上來自首\n: 我也完全沒有辦法阻止爸媽投票\n: 唯一能做的就是我跟我弟\n: 投票給另一邊抵消那兩票\n: 到底爸媽是狂熱韓粉該怎麼辦？\n那我也來自首\n我老家在台中霧峰\n一整個家子全都是藍營鐵票倉\n我過年回家吃年夜飯會被圍起來噴爆的那種（因為我是唯一男長孫....）\n有試過改革\n但只有被圍剿的份\n\n你還能打平\n我這邊算上在台北的我媽我妹抵銷完\n韓總可是扎扎實實的領先了25票左右==\n拜託各位鄉民幫個忙\n一定要出門投票QQ\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 111.71.16.114 (臺灣)\n※ 文章網址: '}
# [問卦] 看到鄉民在看PTT當下該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100836.A.48E.html
# {'Title': '[問卦] 看到鄉民在看PTT當下該怎麼辦？', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100836.A.48E.html', 'Author': 'johnhmj (耗呆肥羊)', 'Description': '\n  剛才  本肥 肚子餓得受不了 O.Q\n\n  騎了一輛大肥羊跑去買小吃的\n\n  麵、豆干、滷蛋、血糕、甜不辣…\n\nhttps://i.imgur.com/XgT8uz7.jpg\n\n  共110元\n\n  等待的時候…\n\n  眼睛瞄到…\n\n  天啊… 驚！\n\n  居然有個鄉民坐著邊吃飯邊看八卦板？！\n\n  啊嘶…\n\n  。\n  。\n  。\n\n  以後遇到鄉民該怎麼辦才好？\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自:
n: 另外，因為中國旅客要去日本旅遊必須先取得簽證，一名在廣州市從事IT產業工作的31歲\n: 陳小姐說，辦理簽證的手續很繁雜，要提出身分證等一堆資料，還不如南韓的簽證來得簡\n: 便。\n: 在成都市工作的31歲陳先生說，自己每年會到日本2到3次，雖然旅行本身讓他非常滿足，\n: 但對交通基礎設施則略有不滿。\n: 陳先生說，日本計程車貴，所以觀光客幾乎都是利用電車移動，但日本電車分成JR跟地下\n: 鐵，車種又分成普通、特急、準急等，讓觀光客很難分得清楚。\n: 他說，明明中國觀光客這麼多，但中文的標示卻意外的少；還有日本很多地方都很難找到\n: 電梯，這對攜帶大型行李的外國觀光客來說十分不便。\n: 在上海市工作的20多歲中國女性說，日本路上很少有垃圾桶，垃圾要丟到哪裡也不清楚；\n: 要辦理退稅經常要長時間排隊，十分沒有效率。\n: 報導指出，中國觀光客已占日本海外觀光客約3成，位居首位，雖然過度依賴中國觀光客\n: 有一定風險，但好不容易成長的情況也必須努力維持，加上2020年又有東京奧運這樣的重\n: 要活動，日本有必要持續致力相關措施，讓所有國家的觀光客都樂於到日本觀光。\n: （譯者：黃名璽/核稿：陳政一）1081223\n: https://www.cna.com.tw/news/aopl/201912230201.aspx\n\n\n-----\nSent from JPTT on my Xiaomi MI 9.\n\n--\n問君能有幾多愁，恰似一群太監上青樓\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 117.136.8.108 (中國)\n'}
# [新聞] 特朗普與習近平和安倍就朝鮮問題進行連
# https://www.ptt.cc/bbs/Gossiping/M.1577100800.A.31B.html
# {'Title': '[新聞] 特朗普與習近平和安倍就朝鮮問題進行連', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100800.A.31B.html', 'Author': 'andrewkuo ()', 'Description': '\n1.媒體來源:\n\n東亞日報\n\n2.記者署名\n\n東京=常駐記者朴亨俊、北京=常駐記者 尹完準 [email\xa0protected]、[email\xa0protected]\n\n3.完整新聞標題:\n\n特朗普與習近平和安倍就朝鮮問題進行連鎖通話\n\n4.完整新聞內文:\n\n美國總統特朗普20日和中國國家主席習近平、21日同日本首相安倍晉三連續通電話，討論\n了朝鮮核問題和貿易談判等問題。據分析，繼美國副國務卿史蒂芬·比根15日至20日連續\n訪問韓中日三國，尋求朝鮮核問題的解決方法後，特朗普總統也親自出面加強國際合作。\n\n\u3000美國白宮在介紹特朗普總統和安倍首相的電話通話時表示：“考慮到最近朝鮮的威脅性\n聲明，雙方壹致同意繼續保持密切的溝通和協調。”特朗普政府把朝鮮的聲明明示為“威\n脅”，這是罕見的。據共同社報道，應特朗普的要求，美日首腦的通話持續了約75分鐘。\n\n\u3000關於朝鮮核問題，中國外交部強調，習近平主席表示“應保持對話和緩和（緊張）局勢\n的勢頭”。在美國表明以強硬方法應對朝鮮的情況下，中國用不同的聲音強調了對朝鮮的\n和解。不過，中國外交部在公開美中首腦的電話通話內容時，相比朝核問題，反而突出習\n近平在通話中強調了美國在臺灣、香港、新疆維吾爾、西藏問題上的不當言行問題。\n\n\u3000此外，特朗普總統20日簽署了《2020財年國防授權法案》，其中包含將駐韓美軍規模維\n持在目前28500人水平的條款。《國防授權法案》作為國防預算的法律根據，包括了警惕向\n同盟過分要求分擔防衛費的條款和強化對朝鮮制裁的條款。\n\n5.完整新聞連結 (或短網址):\n\nhttps://tinyurl.com/w65uwxd\n\n6.備註:\n\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 175.183.33.61 (臺灣)\n'}
# [問卦] 木曜一日有辦法重返榮耀嗎
# https://www.ptt.cc/bbs/Gossiping/M.1577100778.A.A7A.html
# {'Title': '[問卦] 木曜一日有辦法重返榮耀嗎', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100778.A.A7A.html', 'Author': 'cezov0514 (大自然小王子)', 'Description': '\n先說，我還滿愛木曜的一日系列的\n\n當初是從一日玉山那兩集開始接觸\n\n覺得這個網路節目相當認真有質感\n\n不是隨便在室內聊天就混一集\n\n怎知自從體力擔當kid離開木曜後\n\n邰哥擺老跟虧妹的比例似乎大增\n\n節目似乎有點走下坡的趨勢\n\n（非個人意見，可以看播放次數）\n\n請問一日系列有辦法重返榮耀嗎\n\n有木有kid當完兵還不回來的八卦？？？？\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 101.137.66.243 (臺灣)\n'}
# [問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？
# https://www.ptt.cc/bbs/Gossiping/M.1577100740.A.36D.html
# {'Title': '[問卦] 欸！剛剛在電車上跟醉漢打架該怎麼辦？', 'URL': 'https://www.ptt.cc/bbs/Gossiping/M.1577100740.A.36D.html', 'Author': 'Qoo20811 (冠宇哥)', 'Description': '\n欸欸欸欸欸\n\n大家豪我冠宇啦\n\n冠宇我剛剛在電車上看到一個超級★正超有★氣質的女森\n\n結果這時候突然跑出一個醉漢再騷擾辣個妹子\n\n冠宇我氣不過就叫他住手\n\n沒想到跟他幹架還打不過反被一個穿惹帥哥西裝的帥哥給救惹\n\n冠宇我非常慚愧\n\n沒想到辣個妹子跟我要了地址說要向我道謝\n\n請問一下冠宇我現在該怎麼做\n\n有木有掛？\n\n--\n※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.45.149.153 (臺灣)\n'}

# %%
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0

# %% [markdown]
# 將上述資料存入Elasticsaerch 並做呈現
# [Hint] : https://elasticsearch-py.readthedocs.io/en/5.6.3/

# %%
from elasticsearch import Elasticsearch
# start server
import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.0.0/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )
#docid 文章寫入ES指定的ID 也可不只定
#doc 文章寫入的本體
def saveES(esindex, docid, doc):
    es = Elasticsearch("127.0.0.1:9200")
    while True :
        try:
            res = es.index(index=esindex, doc_type="ptt", id=docid, body=doc)
            print(res)
            break
        except Exception as e:
            print(e)
            time.sleep(5)
            print("Es Connection Failed Try again")
# wait a bit then test


# !curl "localhost:9200/_search" -H "Content-Type: application/json" -XGET -d '{
# "query": {
#     "match": {
#       "message": "剛剛在電車上"
#     }
#   },
#   "aggregations": {
#     "top_10_states": {
#       "terms": {
#         "field": "state",
#         "size": 10
#       }
#     }
#   }
# }'
# Out:
#   File "<ipython-input-34-8b732f64767b>", line 24
#     "query": {
#     ^
# IndentationError: unexpected indent
